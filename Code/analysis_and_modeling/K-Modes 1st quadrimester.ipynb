# %%
import pandas as pd
import numpy as np
import feather
import matplotlib as mpl
mpl.use('nbAgg')
import matplotlib.pyplot as plt
from sklearn import preprocessing
import sklearn.model_selection as ms
from sklearn import linear_model
import numpy as np
import numpy.random as nr
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as ss
import math
from kmodes.kmodes import KModes


# %matplotlib inline

# %%
dset = pd.read_csv('../../Data/For_analysis_and_modeling/1st_quadrimester/pred_analys_personal_data.csv', sep = '|')
dset.drop(['1st_model','2nd_model'],axis=1,inplace=True)

# %%
dset.head()
# Out:
#                                             des_plan anio_apertura_expediente  \
# 0  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 1  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 2  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 3  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 4  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
#
#    abandona convocatoria_acceso             des_acceso sexo     lugar_origen  \
# 0         0                 JUN           Selectividad    H  MISMO_MUNICIPIO
# 1         0                 JUN           Selectividad    D   OTRA_COMUNIDAD
# 2         1                 JUN  Formación Profesional    H   OTRA_COMUNIDAD
# 3         0                 JUN  Formación Profesional    D   OTRO_MUNICIPIO
# 4         1                 JUN           Selectividad    D   OTRO_MUNICIPIO
#
#     edad_acceso becario nota_admision_def_interval cum_absent_ratio  \
# 0  (20.0, 25.0]       N                 (6.5, 8.0]   (-0.001, 0.25]
# 1  (20.0, 25.0]       S                 (6.5, 8.0]   (-0.001, 0.25]
# 2  (30.0, 35.0]       S                 (6.5, 8.0]      (0.5, 0.75]
# 3  (25.0, 30.0]       N                 (6.5, 8.0]   (-0.001, 0.25]
# 4  (20.0, 25.0]       N                 (6.5, 8.0]   (-0.001, 0.25]
#
#    cum_pass_ratio  expediente  cod_plan
# 0  (-0.001, 0.25]           1      1623
# 1     (0.25, 0.5]           2      1623
# 2  (-0.001, 0.25]           3      1623
# 3  (-0.001, 0.25]           4      1623
# 4     (0.25, 0.5]           5      1623

# %%
dset.isnull().sum()
# Out:
# des_plan                      0
# anio_apertura_expediente      0
# abandona                      0
# convocatoria_acceso           0
# des_acceso                    0
# sexo                          0
# lugar_origen                  0
# edad_acceso                   0
# becario                       0
# nota_admision_def_interval    0
# cum_absent_ratio              0
# cum_pass_ratio                0
# expediente                    0
# cod_plan                      0
# dtype: int64

# %%
dset['exp_cod_plan'] = dset.apply(lambda func: str(func.cod_plan) + str(func.expediente),axis=1)
dset.drop(['expediente','cod_plan'],axis=1,inplace=True)

# %%
dset.head()
# Out:
#                                             des_plan anio_apertura_expediente  \
# 0  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 1  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 2  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 3  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 4  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
#
#    abandona convocatoria_acceso             des_acceso sexo     lugar_origen  \
# 0         0                 JUN           Selectividad    H  MISMO_MUNICIPIO
# 1         0                 JUN           Selectividad    D   OTRA_COMUNIDAD
# 2         1                 JUN  Formación Profesional    H   OTRA_COMUNIDAD
# 3         0                 JUN  Formación Profesional    D   OTRO_MUNICIPIO
# 4         1                 JUN           Selectividad    D   OTRO_MUNICIPIO
#
#     edad_acceso becario nota_admision_def_interval cum_absent_ratio  \
# 0  (20.0, 25.0]       N                 (6.5, 8.0]   (-0.001, 0.25]
# 1  (20.0, 25.0]       S                 (6.5, 8.0]   (-0.001, 0.25]
# 2  (30.0, 35.0]       S                 (6.5, 8.0]      (0.5, 0.75]
# 3  (25.0, 30.0]       N                 (6.5, 8.0]   (-0.001, 0.25]
# 4  (20.0, 25.0]       N                 (6.5, 8.0]   (-0.001, 0.25]
#
#    cum_pass_ratio exp_cod_plan
# 0  (-0.001, 0.25]        16231
# 1     (0.25, 0.5]        16232
# 2  (-0.001, 0.25]        16233
# 3  (-0.001, 0.25]        16234
# 4     (0.25, 0.5]        16235

# %%
dset['nota_admision_def_interval'].value_counts()
# Out:
# (6.5, 8.0]      1251
# (4.999, 6.5]     631
# (8.0, 9.5]       224
# (10.0, 11.5]      89
# (11.5, 13.0]      45
# (9.5, 10.0]       37
# (13.0, 14.0]       5
# Name: nota_admision_def_interval, dtype: int64

# %%
dset.isnull().sum()
# Out:
# des_plan                      0
# anio_apertura_expediente      0
# abandona                      0
# convocatoria_acceso           0
# des_acceso                    0
# sexo                          0
# lugar_origen                  0
# edad_acceso                   0
# becario                       0
# nota_admision_def_interval    0
# cum_absent_ratio              0
# cum_pass_ratio                0
# exp_cod_plan                  0
# dtype: int64

# %%
# Import module for data manipulation
import pandas as pd
# Import module for linear algebra
import numpy as np
# Import module for data visualization
from plotnine import *
import plotnine
# Data visualization with matplotlib
import matplotlib.pyplot as plt
# Use the theme of ggplot
plt.style.use('ggplot')
# Import module for k-protoype cluster
from kmodes.kmodes import KModes

# %%
dfMatrix = dset.loc[:, dset.columns != 'exp_cod_plan'].to_numpy()
dfMatrix
# Out:
# array([['GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIVILES', '2009-10',
#         0, ..., '(6.5, 8.0]', '(-0.001, 0.25]', '(-0.001, 0.25]'],
#        ['GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIVILES', '2009-10',
#         0, ..., '(6.5, 8.0]', '(-0.001, 0.25]', '(0.25, 0.5]'],
#        ['GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIVILES', '2009-10',
#         1, ..., '(6.5, 8.0]', '(0.5, 0.75]', '(-0.001, 0.25]'],
#        ...,
#        ['GRADO EN INGENIERÍA INFORMÁTICA EN INGENIERÍA DEL SOFTWARE',
#         '2016-17', 1, ..., '(6.5, 8.0]', '(-0.001, 0.25]',
#         '(-0.001, 0.25]'],
#        ['GRADO EN INGENIERÍA INFORMÁTICA EN INGENIERÍA DEL SOFTWARE',
#         '2016-17', 1, ..., '(6.5, 8.0]', '(0.25, 0.5]', '(-0.001, 0.25]'],
#        ['GRADO EN INGENIERÍA INFORMÁTICA EN INGENIERÍA DEL SOFTWARE',
#         '2016-17', 1, ..., '(4.999, 6.5]', '(0.5, 0.75]',
#         '(-0.001, 0.25]']], dtype=object)

# %%
# Choosing optimal K
cost = []
for cluster in range(1, 10):
    kmodes = KModes(n_jobs = -1, n_clusters = cluster, init = 'Huang', random_state = 0)
    kmodes.fit_predict(dfMatrix)
    cost.append(kmodes.cost_)
    print('Cluster initiation: {}'.format(cluster))
# Converting the results into a dataframe and plotting them
df_cost = pd.DataFrame({'Cluster': range(1, 10), 'Cost': cost})
# Data viz
plotnine.options.figure_size = (8, 4.8)
(
    ggplot(data = df_cost)+
    geom_line(aes(x = 'Cluster',
                  y = 'Cost'))+
    geom_point(aes(x = 'Cluster',
                   y = 'Cost'))+
    geom_label(aes(x = 'Cluster',
                   y = 'Cost',
                   label = 'Cluster'),
               size = 10,
               nudge_y = 1000) +
    labs(title = 'Optimal number of cluster with Elbow Method')+
    xlab('Number of Clusters k')+
    ylab('Cost')+
    theme_minimal()
)
# Out:
# Cluster initiation: 1
# Cluster initiation: 2
# Cluster initiation: 3
# Cluster initiation: 4
# Cluster initiation: 5
# Cluster initiation: 6
# Cluster initiation: 7
# Cluster initiation: 8
# Cluster initiation: 9
# <ggplot: (8776993877420)>

# %% [markdown]
# Probaremos con 5

# %%
# Fit the cluster
kmodes = KModes(n_jobs = -1, n_clusters = 5, init = 'Huang', random_state = 0)
kmodes.fit_predict(dfMatrix)
# Add the cluster to the dataframe
dset['Cluster Labels'] = kmodes.labels_

# %%
dset.head()
# Out:
#                                             des_plan anio_apertura_expediente  \
# 0  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 1  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 2  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 3  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 4  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
#
#    abandona convocatoria_acceso             des_acceso sexo     lugar_origen  \
# 0         0                 JUN           Selectividad    H  MISMO_MUNICIPIO
# 1         0                 JUN           Selectividad    D   OTRA_COMUNIDAD
# 2         1                 JUN  Formación Profesional    H   OTRA_COMUNIDAD
# 3         0                 JUN  Formación Profesional    D   OTRO_MUNICIPIO
# 4         1                 JUN           Selectividad    D   OTRO_MUNICIPIO
#
#     edad_acceso becario nota_admision_def_interval cum_absent_ratio  \
# 0  (20.0, 25.0]       N                 (6.5, 8.0]   (-0.001, 0.25]
# 1  (20.0, 25.0]       S                 (6.5, 8.0]   (-0.001, 0.25]
# 2  (30.0, 35.0]       S                 (6.5, 8.0]      (0.5, 0.75]
# 3  (25.0, 30.0]       N                 (6.5, 8.0]   (-0.001, 0.25]
# 4  (20.0, 25.0]       N                 (6.5, 8.0]   (-0.001, 0.25]
#
#    cum_pass_ratio exp_cod_plan  Cluster Labels
# 0  (-0.001, 0.25]        16231               1
# 1     (0.25, 0.5]        16232               1
# 2  (-0.001, 0.25]        16233               0
# 3  (-0.001, 0.25]        16234               1
# 4     (0.25, 0.5]        16235               1

# %%
dset['Cluster Labels'].value_counts()
# Out:
# 1    781
# 0    548
# 3    338
# 2    334
# 4    281
# Name: Cluster Labels, dtype: int64

# %%
dset.to_csv('../../Data/For_analysis_and_modeling/1st_quadrimester/cluster_analys_data.csv')
