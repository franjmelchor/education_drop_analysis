# %%
import pandas as pd
import numpy as np
import feather
import matplotlib as mpl
mpl.use('nbAgg')
import matplotlib.pyplot as plt
from sklearn import preprocessing
import sklearn.model_selection as ms
from sklearn import linear_model
import numpy as np
import numpy.random as nr
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as ss
import math
from kmodes.kmodes import KModes


# %matplotlib inline

# %%
dset = pd.read_csv('../../Data/For_analysis_and_modeling/7th_quadrimester/pred_analys_personal_data.csv', sep = '|')
dset.drop(['1st_model','2nd_model','3rd_model','4th_model','5th_model','6th_model','7th_model','8th_model'],axis=1,inplace=True)

# %%
dset.head()
# Out:
#                                             des_plan anio_apertura_expediente  \
# 0  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 1  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 2  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 3  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 4  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
#
#    abandona convocatoria_acceso             des_acceso sexo   edad_acceso  \
# 0         0                 JUN           Selectividad    H  (20.0, 25.0]
# 1         0                 JUN           Selectividad    D  (20.0, 25.0]
# 2         0                 JUN  Formación Profesional    D  (25.0, 30.0]
# 3         0                 JUN           Selectividad    H  (20.0, 25.0]
# 4         1                 JUN  Formación Profesional    H  (25.0, 30.0]
#
#   becario nota_admision_def_interval cum_more_1st_call_ratio cum_pass_ratio  \
# 0       N                 (6.5, 8.0]             (0.25, 0.5]    (0.25, 0.5]
# 1       S                 (6.5, 8.0]             (0.25, 0.5]    (0.25, 0.5]
# 2       N                 (6.5, 8.0]             (0.25, 0.5]    (0.25, 0.5]
# 3       N                 (6.5, 8.0]          (-0.001, 0.25]    (0.5, 0.75]
# 4       N                 (8.0, 9.5]          (-0.001, 0.25]    (0.25, 0.5]
#
#   cum_absent_ratio  expediente  cod_plan cum_median_interval
# 0      (0.25, 0.5]           1      1623          (3.0, 4.5]
# 1   (-0.001, 0.25]           2      1623          (4.5, 6.0]
# 2      (0.25, 0.5]           4      1623          (3.0, 4.5]
# 3   (-0.001, 0.25]           6      1623          (6.0, 7.5]
# 4      (0.5, 0.75]           7      1623          (4.5, 6.0]

# %%
dset.isnull().sum()
# Out:
# des_plan                      0
# anio_apertura_expediente      0
# abandona                      0
# convocatoria_acceso           0
# des_acceso                    0
# sexo                          0
# edad_acceso                   0
# becario                       0
# nota_admision_def_interval    0
# cum_more_1st_call_ratio       0
# cum_pass_ratio                0
# cum_absent_ratio              0
# expediente                    0
# cod_plan                      0
# cum_median_interval           0
# dtype: int64

# %%
dset['exp_cod_plan'] = dset.apply(lambda func: str(func.cod_plan) + str(func.expediente),axis=1)
dset.drop(['expediente','cod_plan'],axis=1,inplace=True)

# %%
dset.head()
# Out:
#                                             des_plan anio_apertura_expediente  \
# 0  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 1  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 2  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 3  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 4  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
#
#    abandona convocatoria_acceso             des_acceso sexo   edad_acceso  \
# 0         0                 JUN           Selectividad    H  (20.0, 25.0]
# 1         0                 JUN           Selectividad    D  (20.0, 25.0]
# 2         0                 JUN  Formación Profesional    D  (25.0, 30.0]
# 3         0                 JUN           Selectividad    H  (20.0, 25.0]
# 4         1                 JUN  Formación Profesional    H  (25.0, 30.0]
#
#   becario nota_admision_def_interval cum_more_1st_call_ratio cum_pass_ratio  \
# 0       N                 (6.5, 8.0]             (0.25, 0.5]    (0.25, 0.5]
# 1       S                 (6.5, 8.0]             (0.25, 0.5]    (0.25, 0.5]
# 2       N                 (6.5, 8.0]             (0.25, 0.5]    (0.25, 0.5]
# 3       N                 (6.5, 8.0]          (-0.001, 0.25]    (0.5, 0.75]
# 4       N                 (8.0, 9.5]          (-0.001, 0.25]    (0.25, 0.5]
#
#   cum_absent_ratio cum_median_interval exp_cod_plan
# 0      (0.25, 0.5]          (3.0, 4.5]        16231
# 1   (-0.001, 0.25]          (4.5, 6.0]        16232
# 2      (0.25, 0.5]          (3.0, 4.5]        16234
# 3   (-0.001, 0.25]          (6.0, 7.5]        16236
# 4      (0.5, 0.75]          (4.5, 6.0]        16237

# %%
dset['nota_admision_def_interval'].value_counts()
# Out:
# (6.5, 8.0]      766
# (4.999, 6.5]    245
# (8.0, 9.5]      138
# (10.0, 11.5]     74
# (11.5, 13.0]     39
# (9.5, 10.0]      28
# (13.0, 14.0]      4
# Name: nota_admision_def_interval, dtype: int64

# %%
dset.isnull().sum()
# Out:
# des_plan                      0
# anio_apertura_expediente      0
# abandona                      0
# convocatoria_acceso           0
# des_acceso                    0
# sexo                          0
# edad_acceso                   0
# becario                       0
# nota_admision_def_interval    0
# cum_more_1st_call_ratio       0
# cum_pass_ratio                0
# cum_absent_ratio              0
# cum_median_interval           0
# exp_cod_plan                  0
# dtype: int64

# %%
# Import module for data manipulation
import pandas as pd
# Import module for linear algebra
import numpy as np
# Import module for data visualization
from plotnine import *
import plotnine
# Data visualization with matplotlib
import matplotlib.pyplot as plt
# Use the theme of ggplot
plt.style.use('ggplot')
# Import module for k-protoype cluster
from kmodes.kmodes import KModes

# %%
dfMatrix = dset.loc[:, dset.columns != 'exp_cod_plan'].to_numpy()
dfMatrix
# Out:
# array([['GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIVILES', '2009-10',
#         0, ..., '(0.25, 0.5]', '(0.25, 0.5]', '(3.0, 4.5]'],
#        ['GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIVILES', '2009-10',
#         0, ..., '(0.25, 0.5]', '(-0.001, 0.25]', '(4.5, 6.0]'],
#        ['GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIVILES', '2009-10',
#         0, ..., '(0.25, 0.5]', '(0.25, 0.5]', '(3.0, 4.5]'],
#        ...,
#        ['GRADO EN INGENIERÍA INFORMÁTICA EN INGENIERÍA DEL SOFTWARE',
#         '2016-17', 1, ..., '(-0.001, 0.25]', '(0.25, 0.5]', '(3.0, 4.5]'],
#        ['GRADO EN INGENIERÍA INFORMÁTICA EN INGENIERÍA DEL SOFTWARE',
#         '2016-17', 0, ..., '(0.5, 0.75]', '(-0.001, 0.25]', '(4.5, 6.0]'],
#        ['GRADO EN INGENIERÍA INFORMÁTICA EN INGENIERÍA DEL SOFTWARE',
#         '2016-17', 0, ..., '(-0.001, 0.25]', '(0.25, 0.5]', '(3.0, 4.5]']],
#       dtype=object)

# %%
# Choosing optimal K
cost = []
for cluster in range(1, 10):
    kmodes = KModes(n_jobs = -1, n_clusters = cluster, init = 'Huang', random_state = 0)
    kmodes.fit_predict(dfMatrix)
    cost.append(kmodes.cost_)
    print('Cluster initiation: {}'.format(cluster))
# Converting the results into a dataframe and plotting them
df_cost = pd.DataFrame({'Cluster': range(1, 10), 'Cost': cost})
# Data viz
plotnine.options.figure_size = (8, 4.8)
(
    ggplot(data = df_cost)+
    geom_line(aes(x = 'Cluster',
                  y = 'Cost'))+
    geom_point(aes(x = 'Cluster',
                   y = 'Cost'))+
    geom_label(aes(x = 'Cluster',
                   y = 'Cost',
                   label = 'Cluster'),
               size = 10,
               nudge_y = 1000) +
    labs(title = 'Optimal number of cluster with Elbow Method')+
    xlab('Number of Clusters k')+
    ylab('Cost')+
    theme_minimal()
)
# Out:
# Cluster initiation: 1
# Cluster initiation: 2
# Cluster initiation: 3
# Cluster initiation: 4
# Cluster initiation: 5
# Cluster initiation: 6
# Cluster initiation: 7
# Cluster initiation: 8
# Cluster initiation: 9
# <ggplot: (8794767035007)>

# %% [markdown]
# Probaremos con 5

# %%
# Fit the cluster
kmodes = KModes(n_jobs = -1, n_clusters = 5, init = 'Huang', random_state = 0)
kmodes.fit_predict(dfMatrix)
# Add the cluster to the dataframe
dset['Cluster Labels'] = kmodes.labels_

# %%
dset.head()
# Out:
#                                             des_plan anio_apertura_expediente  \
# 0  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 1  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 2  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 3  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
# 4  GRADO EN INGENIERÍA CIVIL - CONSTRUCCIONES CIV...                  2009-10
#
#    abandona convocatoria_acceso             des_acceso sexo   edad_acceso  \
# 0         0                 JUN           Selectividad    H  (20.0, 25.0]
# 1         0                 JUN           Selectividad    D  (20.0, 25.0]
# 2         0                 JUN  Formación Profesional    D  (25.0, 30.0]
# 3         0                 JUN           Selectividad    H  (20.0, 25.0]
# 4         1                 JUN  Formación Profesional    H  (25.0, 30.0]
#
#   becario nota_admision_def_interval cum_more_1st_call_ratio cum_pass_ratio  \
# 0       N                 (6.5, 8.0]             (0.25, 0.5]    (0.25, 0.5]
# 1       S                 (6.5, 8.0]             (0.25, 0.5]    (0.25, 0.5]
# 2       N                 (6.5, 8.0]             (0.25, 0.5]    (0.25, 0.5]
# 3       N                 (6.5, 8.0]          (-0.001, 0.25]    (0.5, 0.75]
# 4       N                 (8.0, 9.5]          (-0.001, 0.25]    (0.25, 0.5]
#
#   cum_absent_ratio cum_median_interval exp_cod_plan  Cluster Labels
# 0      (0.25, 0.5]          (3.0, 4.5]        16231               0
# 1   (-0.001, 0.25]          (4.5, 6.0]        16232               0
# 2      (0.25, 0.5]          (3.0, 4.5]        16234               1
# 3   (-0.001, 0.25]          (6.0, 7.5]        16236               0
# 4      (0.5, 0.75]          (4.5, 6.0]        16237               1

# %%
dset['Cluster Labels'].value_counts()
# Out:
# 0    486
# 3    225
# 2    217
# 4    192
# 1    174
# Name: Cluster Labels, dtype: int64

# %%
dset.to_csv('../../Data/For_analysis_and_modeling/7th_quadrimester/cluster_analys_data.csv')
